# %%
with open('test.txt') as files:
    output = {}
    for line in files.readlines():
        line = line.strip()
        if line.count(',') == 1:
            output[line] = []
            currentPoint = line
        else:
            temp = list(map(float, line.split(',')))
            output[currentPoint].append(temp)

# %%
len(output)
# Out:
# 9

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
def convert_to_cm(x, y):
    dWidth = 58.5
    dHeight = 104.05
    screenWidth = 375
    screenHeight = 667
#             let dX = 18.61
#         let dY = 8.03
    dx = 18.61
    dy = 8.03
    x = x/screenWidth*dWidth
    y = y/screenHeight*dHeight
    x -= dx
    y = y + dy
    return (x/10, y/10)

convert_to_cm(1, 1)

def euclidean_distance(x1, y1, x2, y2):
    return np.sqrt( (x1-x2)**2 + (y1-y2)**2)

# %%
count = 0
for index, key in enumerate(output):
    if(len(output[key]) < 5):
        continue
    fig, axes = plt.subplots()
    axes.set_xlim(0, 375)
    axes.set_ylim(-675, 0)
    x, y = list(map(float, key.split(',')))
    y = -y
    print(x,y)
    axes.scatter(x, y, color='red')
    x1, y1 = convert_to_cm(x, y)
    for i in output[key]:
        pre_x, pre_y = i[2], -i[3]
        axes.scatter(pre_x, pre_y, color='blue')
        x2, y2 = convert_to_cm(pre_x, pre_y)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (187.0, -166.0)
# (153.349358974359, -400.25609082172)
# (242.804987980769, -232.734842023066)
# (98.7933193108974, -210.949567515617)
# (-59.4911858974359, -140.710837638155)
# (197.169471153846, -293.082556463239)
# (112.385379106571, -411.524336256607)
# <img src="data:image/png;base64,..." width="640">
# (93.0, -500.0)
# (226.654146634615, -303.349180081691)
# (32.7188501602564, -88.1256922753484)
# (135.077937199519, -182.653751201346)
# (100.092272636218, -232.234031114849)
# (96.289312900641, -286.572014656415)
# (220.519330929487, -377.970005406055)
# (16.3802083333333, -192.169158457472)
# <img src="data:image/png;base64,..." width="640">
# (281.0, -333.0)
# (-3.58924278846154, -185.283008469486)
# (-88.1620592948718, -173.76435758049)
# (89.3719951923077, -463.859076165305)
# (92.7054537259615, -275.05336376742)
# (117.103866185897, -428.051096227775)
# (74.0349559294872, -367.452976333493)
# (-19.1766826923077, -431.556772585296)
# <img src="data:image/png;base64,..." width="640">
# (187.0, -500.0)
# (97.1500651041667, -375.465950864969)
# (209.564302884615, -304.350801898126)
# (146.44769130609, -435.312854396925)
# (265.654046474359, -373.713112686209)
# (240.613982371795, -139.083202186449)
# (-87.9116586538462, -251.76565653532)
# (158.138271233974, -158.489624879865)
# <img src="data:image/png;base64,..." width="640">
# (93.0, -166.0)
# (5.98858173076923, -322.129589139837)
# (156.980168269231, -271.798092864008)
# (12.7493990384615, -285.820798294089)
# (224.838741987179, -439.820152570879)
# (56.8199118589744, -223.469840221048)
# (79.8254707532051, -246.757547453148)
# (75.6625600961538, -170.884694858241)
# (21.5760216346154, -226.224300216242)
# (-95.4236778846154, -198.053686629024)
# <img src="data:image/png;base64,..." width="640">
# (281.0, -500.0)
# (117.777796036158, -318.874318236425)
# (244.432592147436, -495.910974291206)
# (91.3752003205128, -218.211325684767)
# (65.3648337339744, -474.376105237866)
# (178.952824519231, -269.794849231139)
# (239.925380608974, -334.149050937049)
# <img src="data:image/png;base64,..." width="640">
# (187.0, -333.0)
# (181.018629807692, -199.556119353676)
# (164.805188301282, -499.416650648727)
# (-137.616185897436, -83.9940022825565)
# (-91.2920673076923, -241.248627462758)
# (-49.8507612179487, -268.292416506487)
# (-25.1862980769231, -104.026438611245)
# (-7.84605368589744, -157.613205790485)
# <img src="data:image/png;base64,..." width="640">
# (281.0, -166.0)
# (-82.5280448717949, -267.290794690053)
# (172.724108573718, -391.241494473811)
# (33.5326522435897, -283.817554661221)
# (112.510579427083, -304.100396444017)
# (150.845352564103, -472.372861604998)
# <img src="data:image/png;base64,..." width="640">
# (93.0, -333.0)
# (83.2684795673077, -110.787385872177)
# (13.8762019230769, -109.284953147525)
# (94.6930088141026, -210.4487566074)
# (148.576096754808, -261.030658337338)
# (95.4911608573718, -231.733220206631)
# (260.39563301282, -268.793227414704)

# %%
count = 0
total = 0
total_out_screen
for index, key in enumerate(output):
    if(len(output[key]) < 5):
        continue
    x, y = list(map(float, key.split(',')))
    x1, y1 = convert_to_cm(x, y)
    for i in output[key]:
        count += 1
        pre_x, pre_y = i[2], i[3]
        print(pre_x, pre_y)
        if pre_x >= 0 and pre_x <= 375 and pre_y >= 0 and pre_y <= 675:
            x2, y2 = convert_to_cm(pre_x, pre_y)
    #         print(x2, i[0])
    #         print(x2, y2)
            total += euclidean_distance(x1, y1, x2, y2)
    #         print(euclidean_distance(x1, y1, x2, y2))
        else:
            total_out_screen += 1
print(total)
print(count)
print(total/count)
# Out:
# (153.349358974359, 400.25609082172)
# (242.804987980769, 232.734842023066)
# (98.7933193108974, 210.949567515617)
# (-59.4911858974359, 140.710837638155)
# (197.169471153846, 293.082556463239)
# (112.385379106571, 411.524336256607)
# (226.654146634615, 303.349180081691)
# (32.7188501602564, 88.1256922753484)
# (135.077937199519, 182.653751201346)
# (100.092272636218, 232.234031114849)
# (96.289312900641, 286.572014656415)
# (220.519330929487, 377.970005406055)
# (16.3802083333333, 192.169158457472)
# (-3.58924278846154, 185.283008469486)
# (-88.1620592948718, 173.76435758049)
# (89.3719951923077, 463.859076165305)
# (92.7054537259615, 275.05336376742)
# (117.103866185897, 428.051096227775)
# (74.0349559294872, 367.452976333493)
# (-19.1766826923077, 431.556772585296)
# (97.1500651041667, 375.465950864969)
# (209.564302884615, 304.350801898126)
# (146.44769130609, 435.312854396925)
# (265.654046474359, 373.713112686209)
# (240.613982371795, 139.083202186449)
# (-87.9116586538462, 251.76565653532)
# (158.138271233974, 158.489624879865)
# (5.98858173076923, 322.129589139837)
# (156.980168269231, 271.798092864008)
# (12.7493990384615, 285.820798294089)
# (224.838741987179, 439.820152570879)
# (56.8199118589744, 223.469840221048)
# (79.8254707532051, 246.757547453148)
# (75.6625600961538, 170.884694858241)
# (21.5760216346154, 226.224300216242)
# (-95.4236778846154, 198.053686629024)
# (117.777796036158, 318.874318236425)
# (244.432592147436, 495.910974291206)
# (91.3752003205128, 218.211325684767)
# (65.3648337339744, 474.376105237866)
# (178.952824519231, 269.794849231139)
# (239.925380608974, 334.149050937049)
# (181.018629807692, 199.556119353676)
# (164.805188301282, 499.416650648727)
# (-137.616185897436, 83.9940022825565)
# (-91.2920673076923, 241.248627462758)
# (-49.8507612179487, 268.292416506487)
# (-25.1862980769231, 104.026438611245)
# (-7.84605368589744, 157.613205790485)
# (-82.5280448717949, 267.290794690053)
# (172.724108573718, 391.241494473811)
# (33.5326522435897, 283.817554661221)
# (112.510579427083, 304.100396444017)
# (150.845352564103, 472.372861604998)
# (83.2684795673077, 110.787385872177)
# (13.8762019230769, 109.284953147525)
# (94.6930088141026, 210.4487566074)
# (148.576096754808, 261.030658337338)
# (95.4911608573718, 231.733220206631)
# (260.39563301282, 268.793227414704)
# 147.718525558
# 60
# 2.46197542596
